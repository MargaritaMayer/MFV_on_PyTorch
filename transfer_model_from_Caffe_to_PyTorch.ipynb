# %%
# !wget -q --show-progress http://dl.caffe.berkeleyvision.org/bvlc_reference_caffenet.caffemodel -O bvlc_reference_caffenet.caffemodel
# Out:
# bvlc_reference_caff 100%[===================>] 232.56M  10.2MB/s    in 31s

# %%
# Download ImageNet labels
# !wget https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt
# Out:
# --2023-05-19 08:13:49--  https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10472 (10K) [text/plain]
# Saving to: ‘imagenet_classes.txt’
#
# imagenet_classes.tx 100%[===================>]  10.23K  --.-KB/s    in 0s
#
# 2023-05-19 08:13:49 (42.3 MB/s) - ‘imagenet_classes.txt’ saved [10472/10472]

# %%
# !apt install -y caffe-cpu
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   blt caffe-tools-cpu cython3 fonts-lyx javascript-common libblosc1
#   libcaffe-cpu1 libgflags2.2 libgoogle-glog0v5 libimagequant0 libjs-jquery
#   libjs-jquery-ui liblbfgsb0 libleveldb1d liblzo2-2 python-matplotlib-data
#   python-tables-data python3-atomicwrites python3-attr python3-backcall
#   python3-blosc python3-bs4 python3-caffe-cpu python3-cloudpickle
#   python3-cycler python3-dask python3-dateutil python3-decorator
#   python3-et-xmlfile python3-fsspec python3-gflags python3-h5py
#   python3-html5lib python3-imageio python3-importlib-metadata python3-ipython
#   python3-ipython-genutils python3-jdcal python3-jedi python3-kiwisolver
#   python3-locket python3-lxml python3-matplotlib python3-more-itertools
#   python3-mpi4py python3-networkx python3-nose python3-numexpr python3-numpy
#   python3-olefile python3-openpyxl python3-packaging python3-pandas
#   python3-pandas-lib python3-parso python3-partd python3-pexpect
#   python3-pickleshare python3-pil python3-pluggy python3-prompt-toolkit
#   python3-protobuf python3-ptyprocess python3-py python3-pygments
#   python3-pyparsing python3-pytest python3-pywt python3-scipy python3-skimage
#   python3-skimage-lib python3-soupsieve python3-tables python3-tables-lib
#   python3-tk python3-toolz python3-traitlets python3-tz python3-wcwidth
#   python3-webencodings python3-xlrd python3-xlwt python3-yaml python3-zipp
#   python3-zmq tk8.6-blt2.5 ttf-bitstream-vera
# Suggested packages:
#   blt-demo libcaffe-cpu-dev caffe-doc cython-doc apache2 | lighttpd | httpd
#   libjs-jquery-ui-docs python-attr-doc python-blosc-doc python-cycler-doc
#   ipython python-dask-doc python3-bcolz python3-boto python3-distributed
#   python3-graphviz python3-psutil python3-sklearn python3-sqlalchemy
#   python-fsspec-doc python-h5py-doc python3-genshi python-imageio-doc
#   python3-astropy python3-gdal python-ipython-doc python3-lxml-dbg
#   python-lxml-doc dvipng gir1.2-gtk-3.0 ghostscript inkscape ipython3
#   python-matplotlib-doc python3-cairocffi python3-gi-cairo python3-gobject
#   python3-pyqt5 python3-sip python3-tornado texlive-extra-utils
#   texlive-latex-extra ttf-staypuft python-networkx-doc python3-pygraphviz
#   | python3-pydot python-nose-doc python-numpy-doc python3-numpy-dbg
#   python-pandas-doc python3-statsmodels python-pexpect-doc python-pil-doc
#   python3-pil-dbg subversion python-pygments-doc python-pyparsing-doc
#   python-scipy-doc python-skimage-doc python3-netcdf4 python-tables-doc
#   vitables tix python3-tk-dbg python-toolz-doc python-xlrt-doc
# The following NEW packages will be installed:
#   blt caffe-cpu caffe-tools-cpu cython3 fonts-lyx javascript-common libblosc1
#   libcaffe-cpu1 libgflags2.2 libgoogle-glog0v5 libimagequant0 libjs-jquery
#   libjs-jquery-ui liblbfgsb0 libleveldb1d liblzo2-2 python-matplotlib-data
#   python-tables-data python3-atomicwrites python3-attr python3-backcall
#   python3-blosc python3-bs4 python3-caffe-cpu python3-cloudpickle
#   python3-cycler python3-dask python3-dateutil python3-decorator
#   python3-et-xmlfile python3-fsspec python3-gflags python3-h5py
#   python3-html5lib python3-imageio python3-importlib-metadata python3-ipython
#   python3-ipython-genutils python3-jdcal python3-jedi python3-kiwisolver
#   python3-locket python3-lxml python3-matplotlib python3-more-itertools
#   python3-mpi4py python3-networkx python3-nose python3-numexpr python3-numpy
#   python3-olefile python3-openpyxl python3-packaging python3-pandas
#   python3-pandas-lib python3-parso python3-partd python3-pexpect
#   python3-pickleshare python3-pil python3-pluggy python3-prompt-toolkit
#   python3-protobuf python3-ptyprocess python3-py python3-pygments
#   python3-pyparsing python3-pytest python3-pywt python3-scipy python3-skimage
#   python3-skimage-lib python3-soupsieve python3-tables python3-tables-lib
#   python3-tk python3-toolz python3-traitlets python3-tz python3-wcwidth
#   python3-webencodings python3-xlrd python3-xlwt python3-yaml python3-zipp
#   python3-zmq tk8.6-blt2.5 ttf-bitstream-vera
# 0 upgraded, 88 newly installed, 0 to remove and 24 not upgraded.
# Need to get 72.2 MB of archives.
# After this operation, 255 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-yaml amd64 5.3.1-1ubuntu0.1 [136 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 tk8.6-blt2.5 amd64 2.5.3+dfsg-4 [572 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 blt amd64 2.5.3+dfsg-4 [4,944 B]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgflags2.2 amd64 2.2.2-1build1 [78.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 libgoogle-glog0v5 amd64 0.4.0-1build1 [51.5 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libleveldb1d amd64 1.22-3ubuntu2 [139 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/universe amd64 libcaffe-cpu1 amd64 1.0.0+git20180821.99bd997-5build3 [790 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/universe amd64 caffe-tools-cpu amd64 1.0.0+git20180821.99bd997-5build3 [1,620 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/universe amd64 cython3 amd64 0.29.14-0.1ubuntu3 [1,474 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-dateutil all 2.7.3-3ubuntu1 [63.3 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-gflags all 1.5.1-7 [35.6 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-numpy amd64 1:1.17.4-5ubuntu3.1 [2,724 kB]
# Get:13 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-mpi4py amd64 3.0.3-4build2 [500 kB]
# Get:14 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-h5py amd64 2.10.0-2build2 [873 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-backcall all 0.1.0-2 [11.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-decorator all 4.4.2-0ubuntu1 [10.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-parso all 0.5.2-1ubuntu1 [62.8 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-jedi all 0.15.2-1 [502 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-ptyprocess all 0.6.0-1ubuntu1 [13.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-pexpect all 4.6.0-1build1 [44.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pickleshare all 0.7.5-2 [7,560 B]
# Get:22 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-wcwidth all 0.1.8+dfsg1-3 [17.4 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-prompt-toolkit all 2.0.10-2 [220 kB]
# Get:24 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-pygments all 2.3.1+dfsg-1ubuntu2.2 [579 kB]
# Get:25 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-ipython-genutils all 0.2.0-1ubuntu1 [21.1 kB]
# Get:26 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-traitlets all 4.3.3-3 [59.9 kB]
# Get:27 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-ipython all 7.13.0-1 [494 kB]
# Get:28 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-lyx all 2.3.4.2-2 [154 kB]
# Get:29 http://archive.ubuntu.com/ubuntu focal/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:30 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-matplotlib-data all 3.1.2-1ubuntu4 [3,788 kB]
# Get:31 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-pyparsing all 2.4.6-1 [61.3 kB]
# Get:32 http://archive.ubuntu.com/ubuntu focal/main amd64 libjs-jquery all 3.3.1~dfsg-3 [329 kB]
# Get:33 http://archive.ubuntu.com/ubuntu focal/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:34 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-cycler all 0.10.0-3 [8,132 B]
# Get:35 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-kiwisolver amd64 1.0.1-3build1 [61.3 kB]
# Get:36 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-matplotlib amd64 3.1.2-1ubuntu4 [4,459 kB]
# Get:37 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-networkx all 2.4-3ubuntu1 [855 kB]
# Get:38 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-nose all 1.3.7-5 [116 kB]
# Get:39 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-tz all 2019.3-1ubuntu0.20.04.0 [24.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pandas-lib amd64 0.25.3+dfsg-7 [4,628 kB]
# Get:41 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pandas all 0.25.3+dfsg-7 [1,968 kB]
# Get:42 http://archive.ubuntu.com/ubuntu focal/main amd64 libimagequant0 amd64 2.12.2-1.1 [31.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-pil amd64 7.0.0-4ubuntu0.7 [366 kB]
# Get:44 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-protobuf amd64 3.6.1.3-2ubuntu5.2 [298 kB]
# Get:45 http://archive.ubuntu.com/ubuntu focal/universe amd64 liblbfgsb0 amd64 3.0+dfsg.3-7build1 [29.5 kB]
# Get:46 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-scipy amd64 1.3.3-3build1 [11.1 MB]
# Get:47 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-skimage-lib amd64 0.16.2-2ubuntu1 [2,217 kB]
# Get:48 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-imageio all 2.4.1-3 [3,187 kB]
# Get:49 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pywt amd64 0.5.1-1.3build1 [998 kB]
# Get:50 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-skimage all 0.16.2-2ubuntu1 [20.5 MB]
# Get:51 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-caffe-cpu amd64 1.0.0+git20180821.99bd997-5build3 [698 kB]
# Get:52 http://archive.ubuntu.com/ubuntu focal/universe amd64 caffe-cpu amd64 1.0.0+git20180821.99bd997-5build3 [4,604 B]
# Get:53 http://archive.ubuntu.com/ubuntu focal/main amd64 javascript-common all 11 [6,066 B]
# Get:54 http://archive.ubuntu.com/ubuntu focal/universe amd64 libblosc1 amd64 1.17.1+ds1-1 [32.2 kB]
# Get:55 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:56 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-tables-data all 3.6.1-2build1 [45.7 kB]
# Get:57 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-atomicwrites all 1.1.5-2build1 [7,016 B]
# Get:58 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-attr all 19.3.0-2 [33.9 kB]
# Get:59 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-blosc amd64 1.7.0+ds1-2ubuntu2 [22.0 kB]
# Get:60 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-soupsieve all 1.9.5+dfsg-1 [29.1 kB]
# Get:61 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-bs4 all 4.8.2-1 [83.0 kB]
# Get:62 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-cloudpickle all 1.3.0-1 [23.4 kB]
# Get:63 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-fsspec all 0.6.1-0.1 [45.7 kB]
# Get:64 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-toolz all 0.9.0-1 [42.0 kB]
# Get:65 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-dask all 2.8.1+dfsg-0.4 [532 kB]
# Get:66 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-et-xmlfile all 1.0.1-2.1 [9,224 B]
# Get:67 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-webencodings all 0.5.1-1ubuntu1 [11.0 kB]
# Get:68 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-html5lib all 1.0.1-2 [84.3 kB]
# Get:69 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-more-itertools all 4.2.0-1build1 [39.4 kB]
# Get:70 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-zipp all 1.0.0-1 [5,312 B]
# Get:71 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-importlib-metadata all 1.5.0-1 [9,992 B]
# Get:72 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-jdcal all 1.0-1.3 [7,944 B]
# Get:73 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-locket all 0.2.0-1 [4,562 B]
# Get:74 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-lxml amd64 4.5.0-1ubuntu0.5 [1,384 kB]
# Get:75 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-numexpr amd64 2.7.1-1build1 [133 kB]
# Get:76 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-olefile all 0.46-2 [33.7 kB]
# Get:77 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-openpyxl all 3.0.3-1 [144 kB]
# Get:78 http://archive.ubuntu.com/ubuntu focal/main amd64 python3-packaging all 20.3-1 [26.8 kB]
# Get:79 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-partd all 1.0.0-1 [14.8 kB]
# Get:80 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pluggy all 0.13.0-2 [18.4 kB]
# Get:81 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-py all 1.8.1-1ubuntu0.1 [65.6 kB]
# Get:82 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-pytest all 4.6.9-1 [178 kB]
# Get:83 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-tables-lib amd64 3.6.1-2build1 [501 kB]
# Get:84 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-tables all 3.6.1-2build1 [333 kB]
# Get:85 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-tk amd64 3.8.10-0ubuntu1~20.04 [104 kB]
# Get:86 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-xlrd all 1.1.0-5 [90.8 kB]
# Get:87 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-xlwt all 1.3.0-3 [83.7 kB]
# Get:88 http://archive.ubuntu.com/ubuntu focal/universe amd64 python3-zmq amd64 18.1.1-3 [294 kB]
# Fetched 72.2 MB in 9s (7,613 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package python3-yaml.
# (Reading database ... 122531 files and directories currently installed.)
# Preparing to unpack .../00-python3-yaml_5.3.1-1ubuntu0.1_amd64.deb ...
# Unpacking python3-yaml (5.3.1-1ubuntu0.1) ...
# Selecting previously unselected package tk8.6-blt2.5.
# Preparing to unpack .../01-tk8.6-blt2.5_2.5.3+dfsg-4_amd64.deb ...
# Unpacking tk8.6-blt2.5 (2.5.3+dfsg-4) ...
# Selecting previously unselected package blt.
# Preparing to unpack .../02-blt_2.5.3+dfsg-4_amd64.deb ...
# Unpacking blt (2.5.3+dfsg-4) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../03-libgflags2.2_2.2.2-1build1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.2-1build1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../04-libgoogle-glog0v5_0.4.0-1build1_amd64.deb ...
# Unpacking libgoogle-glog0v5 (0.4.0-1build1) ...
# Selecting previously unselected package libleveldb1d:amd64.
# Preparing to unpack .../05-libleveldb1d_1.22-3ubuntu2_amd64.deb ...
# Unpacking libleveldb1d:amd64 (1.22-3ubuntu2) ...
# Selecting previously unselected package libcaffe-cpu1:amd64.
# Preparing to unpack .../06-libcaffe-cpu1_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking libcaffe-cpu1:amd64 (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package caffe-tools-cpu.
# Preparing to unpack .../07-caffe-tools-cpu_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking caffe-tools-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package cython3.
# Preparing to unpack .../08-cython3_0.29.14-0.1ubuntu3_amd64.deb ...
# Unpacking cython3 (0.29.14-0.1ubuntu3) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../09-python3-dateutil_2.7.3-3ubuntu1_all.deb ...
# Unpacking python3-dateutil (2.7.3-3ubuntu1) ...
# Selecting previously unselected package python3-gflags.
# Preparing to unpack .../10-python3-gflags_1.5.1-7_all.deb ...
# Unpacking python3-gflags (1.5.1-7) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../11-python3-numpy_1%3a1.17.4-5ubuntu3.1_amd64.deb ...
# Unpacking python3-numpy (1:1.17.4-5ubuntu3.1) ...
# Selecting previously unselected package python3-mpi4py.
# Preparing to unpack .../12-python3-mpi4py_3.0.3-4build2_amd64.deb ...
# Unpacking python3-mpi4py (3.0.3-4build2) ...
# Selecting previously unselected package python3-h5py.
# Preparing to unpack .../13-python3-h5py_2.10.0-2build2_amd64.deb ...
# Unpacking python3-h5py (2.10.0-2build2) ...
# Selecting previously unselected package python3-backcall.
# Preparing to unpack .../14-python3-backcall_0.1.0-2_all.deb ...
# Unpacking python3-backcall (0.1.0-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../15-python3-decorator_4.4.2-0ubuntu1_all.deb ...
# Unpacking python3-decorator (4.4.2-0ubuntu1) ...
# Selecting previously unselected package python3-parso.
# Preparing to unpack .../16-python3-parso_0.5.2-1ubuntu1_all.deb ...
# Unpacking python3-parso (0.5.2-1ubuntu1) ...
# Selecting previously unselected package python3-jedi.
# Preparing to unpack .../17-python3-jedi_0.15.2-1_all.deb ...
# Unpacking python3-jedi (0.15.2-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../18-python3-ptyprocess_0.6.0-1ubuntu1_all.deb ...
# Unpacking python3-ptyprocess (0.6.0-1ubuntu1) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../19-python3-pexpect_4.6.0-1build1_all.deb ...
# Unpacking python3-pexpect (4.6.0-1build1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../20-python3-pickleshare_0.7.5-2_all.deb ...
# Unpacking python3-pickleshare (0.7.5-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../21-python3-wcwidth_0.1.8+dfsg1-3_all.deb ...
# Unpacking python3-wcwidth (0.1.8+dfsg1-3) ...
# Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../22-python3-prompt-toolkit_2.0.10-2_all.deb ...
# Unpacking python3-prompt-toolkit (2.0.10-2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../23-python3-pygments_2.3.1+dfsg-1ubuntu2.2_all.deb ...
# Unpacking python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../24-python3-ipython-genutils_0.2.0-1ubuntu1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../25-python3-traitlets_4.3.3-3_all.deb ...
# Unpacking python3-traitlets (4.3.3-3) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../26-python3-ipython_7.13.0-1_all.deb ...
# Unpacking python3-ipython (7.13.0-1) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../27-fonts-lyx_2.3.4.2-2_all.deb ...
# Unpacking fonts-lyx (2.3.4.2-2) ...
# Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../28-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../29-python-matplotlib-data_3.1.2-1ubuntu4_all.deb ...
# Unpacking python-matplotlib-data (3.1.2-1ubuntu4) ...
# Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../30-python3-pyparsing_2.4.6-1_all.deb ...
# Unpacking python3-pyparsing (2.4.6-1) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../31-libjs-jquery_3.3.1~dfsg-3_all.deb ...
# Unpacking libjs-jquery (3.3.1~dfsg-3) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../32-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# Selecting previously unselected package python3-cycler.
# Preparing to unpack .../33-python3-cycler_0.10.0-3_all.deb ...
# Unpacking python3-cycler (0.10.0-3) ...
# Selecting previously unselected package python3-kiwisolver.
# Preparing to unpack .../34-python3-kiwisolver_1.0.1-3build1_amd64.deb ...
# Unpacking python3-kiwisolver (1.0.1-3build1) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../35-python3-matplotlib_3.1.2-1ubuntu4_amd64.deb ...
# Unpacking python3-matplotlib (3.1.2-1ubuntu4) ...
# Selecting previously unselected package python3-networkx.
# Preparing to unpack .../36-python3-networkx_2.4-3ubuntu1_all.deb ...
# Unpacking python3-networkx (2.4-3ubuntu1) ...
# Selecting previously unselected package python3-nose.
# Preparing to unpack .../37-python3-nose_1.3.7-5_all.deb ...
# Unpacking python3-nose (1.3.7-5) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../38-python3-tz_2019.3-1ubuntu0.20.04.0_all.deb ...
# Unpacking python3-tz (2019.3-1ubuntu0.20.04.0) ...
# Selecting previously unselected package python3-pandas-lib.
# Preparing to unpack .../39-python3-pandas-lib_0.25.3+dfsg-7_amd64.deb ...
# Unpacking python3-pandas-lib (0.25.3+dfsg-7) ...
# Selecting previously unselected package python3-pandas.
# Preparing to unpack .../40-python3-pandas_0.25.3+dfsg-7_all.deb ...
# Unpacking python3-pandas (0.25.3+dfsg-7) ...
# Selecting previously unselected package libimagequant0:amd64.
# Preparing to unpack .../41-libimagequant0_2.12.2-1.1_amd64.deb ...
# Unpacking libimagequant0:amd64 (2.12.2-1.1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../42-python3-pil_7.0.0-4ubuntu0.7_amd64.deb ...
# Unpacking python3-pil:amd64 (7.0.0-4ubuntu0.7) ...
# Selecting previously unselected package python3-protobuf.
# Preparing to unpack .../43-python3-protobuf_3.6.1.3-2ubuntu5.2_amd64.deb ...
# Unpacking python3-protobuf (3.6.1.3-2ubuntu5.2) ...
# Selecting previously unselected package liblbfgsb0:amd64.
# Preparing to unpack .../44-liblbfgsb0_3.0+dfsg.3-7build1_amd64.deb ...
# Unpacking liblbfgsb0:amd64 (3.0+dfsg.3-7build1) ...
# Selecting previously unselected package python3-scipy.
# Preparing to unpack .../45-python3-scipy_1.3.3-3build1_amd64.deb ...
# Unpacking python3-scipy (1.3.3-3build1) ...
# Selecting previously unselected package python3-skimage-lib:amd64.
# Preparing to unpack .../46-python3-skimage-lib_0.16.2-2ubuntu1_amd64.deb ...
# Unpacking python3-skimage-lib:amd64 (0.16.2-2ubuntu1) ...
# Selecting previously unselected package python3-imageio.
# Preparing to unpack .../47-python3-imageio_2.4.1-3_all.deb ...
# Unpacking python3-imageio (2.4.1-3) ...
# Selecting previously unselected package python3-pywt.
# Preparing to unpack .../48-python3-pywt_0.5.1-1.3build1_amd64.deb ...
# Unpacking python3-pywt (0.5.1-1.3build1) ...
# Selecting previously unselected package python3-skimage.
# Preparing to unpack .../49-python3-skimage_0.16.2-2ubuntu1_all.deb ...
# Unpacking python3-skimage (0.16.2-2ubuntu1) ...
# Selecting previously unselected package python3-caffe-cpu.
# Preparing to unpack .../50-python3-caffe-cpu_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking python3-caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package caffe-cpu.
# Preparing to unpack .../51-caffe-cpu_1.0.0+git20180821.99bd997-5build3_amd64.deb ...
# Unpacking caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../52-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libblosc1.
# Preparing to unpack .../53-libblosc1_1.17.1+ds1-1_amd64.deb ...
# Unpacking libblosc1 (1.17.1+ds1-1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../54-liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package python-tables-data.
# Preparing to unpack .../55-python-tables-data_3.6.1-2build1_all.deb ...
# Unpacking python-tables-data (3.6.1-2build1) ...
# Selecting previously unselected package python3-atomicwrites.
# Preparing to unpack .../56-python3-atomicwrites_1.1.5-2build1_all.deb ...
# Unpacking python3-atomicwrites (1.1.5-2build1) ...
# Selecting previously unselected package python3-attr.
# Preparing to unpack .../57-python3-attr_19.3.0-2_all.deb ...
# Unpacking python3-attr (19.3.0-2) ...
# Selecting previously unselected package python3-blosc.
# Preparing to unpack .../58-python3-blosc_1.7.0+ds1-2ubuntu2_amd64.deb ...
# Unpacking python3-blosc (1.7.0+ds1-2ubuntu2) ...
# Selecting previously unselected package python3-soupsieve.
# Preparing to unpack .../59-python3-soupsieve_1.9.5+dfsg-1_all.deb ...
# Unpacking python3-soupsieve (1.9.5+dfsg-1) ...
# Selecting previously unselected package python3-bs4.
# Preparing to unpack .../60-python3-bs4_4.8.2-1_all.deb ...
# Unpacking python3-bs4 (4.8.2-1) ...
# Selecting previously unselected package python3-cloudpickle.
# Preparing to unpack .../61-python3-cloudpickle_1.3.0-1_all.deb ...
# Unpacking python3-cloudpickle (1.3.0-1) ...
# Selecting previously unselected package python3-fsspec.
# Preparing to unpack .../62-python3-fsspec_0.6.1-0.1_all.deb ...
# Unpacking python3-fsspec (0.6.1-0.1) ...
# Selecting previously unselected package python3-toolz.
# Preparing to unpack .../63-python3-toolz_0.9.0-1_all.deb ...
# Unpacking python3-toolz (0.9.0-1) ...
# Selecting previously unselected package python3-dask.
# Preparing to unpack .../64-python3-dask_2.8.1+dfsg-0.4_all.deb ...
# Unpacking python3-dask (2.8.1+dfsg-0.4) ...
# Selecting previously unselected package python3-et-xmlfile.
# Preparing to unpack .../65-python3-et-xmlfile_1.0.1-2.1_all.deb ...
# Unpacking python3-et-xmlfile (1.0.1-2.1) ...
# Selecting previously unselected package python3-webencodings.
# Preparing to unpack .../66-python3-webencodings_0.5.1-1ubuntu1_all.deb ...
# Unpacking python3-webencodings (0.5.1-1ubuntu1) ...
# Selecting previously unselected package python3-html5lib.
# Preparing to unpack .../67-python3-html5lib_1.0.1-2_all.deb ...
# Unpacking python3-html5lib (1.0.1-2) ...
# Selecting previously unselected package python3-more-itertools.
# Preparing to unpack .../68-python3-more-itertools_4.2.0-1build1_all.deb ...
# Unpacking python3-more-itertools (4.2.0-1build1) ...
# Selecting previously unselected package python3-zipp.
# Preparing to unpack .../69-python3-zipp_1.0.0-1_all.deb ...
# Unpacking python3-zipp (1.0.0-1) ...
# Selecting previously unselected package python3-importlib-metadata.
# Preparing to unpack .../70-python3-importlib-metadata_1.5.0-1_all.deb ...
# Unpacking python3-importlib-metadata (1.5.0-1) ...
# Selecting previously unselected package python3-jdcal.
# Preparing to unpack .../71-python3-jdcal_1.0-1.3_all.deb ...
# Unpacking python3-jdcal (1.0-1.3) ...
# Selecting previously unselected package python3-locket.
# Preparing to unpack .../72-python3-locket_0.2.0-1_all.deb ...
# Unpacking python3-locket (0.2.0-1) ...
# Selecting previously unselected package python3-lxml:amd64.
# Preparing to unpack .../73-python3-lxml_4.5.0-1ubuntu0.5_amd64.deb ...
# Unpacking python3-lxml:amd64 (4.5.0-1ubuntu0.5) ...
# Selecting previously unselected package python3-numexpr.
# Preparing to unpack .../74-python3-numexpr_2.7.1-1build1_amd64.deb ...
# Unpacking python3-numexpr (2.7.1-1build1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../75-python3-olefile_0.46-2_all.deb ...
# Unpacking python3-olefile (0.46-2) ...
# Selecting previously unselected package python3-openpyxl.
# Preparing to unpack .../76-python3-openpyxl_3.0.3-1_all.deb ...
# Unpacking python3-openpyxl (3.0.3-1) ...
# Selecting previously unselected package python3-packaging.
# Preparing to unpack .../77-python3-packaging_20.3-1_all.deb ...
# Unpacking python3-packaging (20.3-1) ...
# Selecting previously unselected package python3-partd.
# Preparing to unpack .../78-python3-partd_1.0.0-1_all.deb ...
# Unpacking python3-partd (1.0.0-1) ...
# Selecting previously unselected package python3-pluggy.
# Preparing to unpack .../79-python3-pluggy_0.13.0-2_all.deb ...
# Unpacking python3-pluggy (0.13.0-2) ...
# Selecting previously unselected package python3-py.
# Preparing to unpack .../80-python3-py_1.8.1-1ubuntu0.1_all.deb ...
# Unpacking python3-py (1.8.1-1ubuntu0.1) ...
# Selecting previously unselected package python3-pytest.
# Preparing to unpack .../81-python3-pytest_4.6.9-1_all.deb ...
# Unpacking python3-pytest (4.6.9-1) ...
# Selecting previously unselected package python3-tables-lib.
# Preparing to unpack .../82-python3-tables-lib_3.6.1-2build1_amd64.deb ...
# Unpacking python3-tables-lib (3.6.1-2build1) ...
# Selecting previously unselected package python3-tables.
# Preparing to unpack .../83-python3-tables_3.6.1-2build1_all.deb ...
# Unpacking python3-tables (3.6.1-2build1) ...
# Selecting previously unselected package python3-tk:amd64.
# Preparing to unpack .../84-python3-tk_3.8.10-0ubuntu1~20.04_amd64.deb ...
# Unpacking python3-tk:amd64 (3.8.10-0ubuntu1~20.04) ...
# Selecting previously unselected package python3-xlrd.
# Preparing to unpack .../85-python3-xlrd_1.1.0-5_all.deb ...
# Unpacking python3-xlrd (1.1.0-5) ...
# Selecting previously unselected package python3-xlwt.
# Preparing to unpack .../86-python3-xlwt_1.3.0-3_all.deb ...
# Unpacking python3-xlwt (1.3.0-3) ...
# Selecting previously unselected package python3-zmq.
# Preparing to unpack .../87-python3-zmq_18.1.1-3_amd64.deb ...
# Unpacking python3-zmq (18.1.1-3) ...
# Setting up python3-more-itertools (4.2.0-1build1) ...
# Setting up javascript-common (11) ...
# Setting up python3-attr (19.3.0-2) ...
# Setting up libleveldb1d:amd64 (1.22-3ubuntu2) ...
# Setting up tk8.6-blt2.5 (2.5.3+dfsg-4) ...
# Setting up ttf-bitstream-vera (1.10-8) ...
# Setting up python3-py (1.8.1-1ubuntu0.1) ...
# Setting up python3-jdcal (1.0-1.3) ...
# Setting up python3-backcall (0.1.0-2) ...
# Setting up python3-parso (0.5.2-1ubuntu1) ...
# Setting up python3-ipython-genutils (0.2.0-1ubuntu1) ...
# Setting up fonts-lyx (2.3.4.2-2) ...
# Setting up python3-olefile (0.46-2) ...
# Setting up blt (2.5.3+dfsg-4) ...
# Setting up python3-fsspec (0.6.1-0.1) ...
# Setting up python3-yaml (5.3.1-1ubuntu0.1) ...
# Setting up python3-tk:amd64 (3.8.10-0ubuntu1~20.04) ...
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up python3-zipp (1.0.0-1) ...
# Setting up python3-mpi4py (3.0.3-4build2) ...
# Setting up python3-nose (1.3.7-5) ...
# Setting up python3-webencodings (0.5.1-1ubuntu1) ...
# Setting up python3-tz (2019.3-1ubuntu0.20.04.0) ...
# Setting up python3-cloudpickle (1.3.0-1) ...
# Setting up python3-atomicwrites (1.1.5-2build1) ...
# Setting up python3-decorator (4.4.2-0ubuntu1) ...
# Setting up python3-pygments (2.3.1+dfsg-1ubuntu2.2) ...
# Setting up python3-wcwidth (0.1.8+dfsg1-3) ...
# Setting up python3-pyparsing (2.4.6-1) ...
# Setting up python3-zmq (18.1.1-3) ...
# Setting up python3-cycler (0.10.0-3) ...
# Setting up libimagequant0:amd64 (2.12.2-1.1) ...
# Setting up python3-kiwisolver (1.0.1-3build1) ...
# Setting up python3-xlwt (1.3.0-3) ...
# Setting up cython3 (0.29.14-0.1ubuntu3) ...
# Setting up python3-html5lib (1.0.1-2) ...
# Setting up python3-numpy (1:1.17.4-5ubuntu3.1) ...
# Setting up python3-pickleshare (0.7.5-2) ...
# Setting up python3-lxml:amd64 (4.5.0-1ubuntu0.5) ...
# Setting up python3-traitlets (4.3.3-3) ...
# Setting up libblosc1 (1.17.1+ds1-1) ...
# Setting up python3-et-xmlfile (1.0.1-2.1) ...
# Setting up python3-xlrd (1.1.0-5) ...
# Setting up python3-toolz (0.9.0-1) ...
# Setting up python3-dateutil (2.7.3-3ubuntu1) ...
# Setting up python3-pywt (0.5.1-1.3build1) ...
# Setting up libjs-jquery (3.3.1~dfsg-3) ...
# Setting up python3-protobuf (3.6.1.3-2ubuntu5.2) ...
# Setting up python-matplotlib-data (3.1.2-1ubuntu4) ...
# Setting up python3-locket (0.2.0-1) ...
# Setting up python3-soupsieve (1.9.5+dfsg-1) ...
# Setting up python-tables-data (3.6.1-2build1) ...
# Setting up python3-gflags (1.5.1-7) ...
# Setting up liblbfgsb0:amd64 (3.0+dfsg.3-7build1) ...
# Setting up libgflags2.2 (2.2.2-1build1) ...
# Setting up python3-ptyprocess (0.6.0-1ubuntu1) ...
# Setting up python3-prompt-toolkit (2.0.10-2) ...
# Setting up python3-partd (1.0.0-1) ...
# Setting up python3-scipy (1.3.3-3build1) ...
# Setting up python3-importlib-metadata (1.5.0-1) ...
# Setting up python3-skimage-lib:amd64 (0.16.2-2ubuntu1) ...
# Setting up python3-jedi (0.15.2-1) ...
# Setting up python3-tables-lib (3.6.1-2build1) ...
# Setting up python3-pandas-lib (0.25.3+dfsg-7) ...
# Setting up python3-dask (2.8.1+dfsg-0.4) ...
# Setting up python3-networkx (2.4-3ubuntu1) ...
# /usr/lib/python3/dist-packages/networkx/readwrite/tests/test_graphml.py:933: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert H.nodes['n1']['special'] is 0
# /usr/lib/python3/dist-packages/networkx/readwrite/tests/test_graphml.py:935: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   assert H.edges['n0','n1',1]['special'] is 0
# Setting up python3-bs4 (4.8.2-1) ...
# Setting up python3-blosc (1.7.0+ds1-2ubuntu2) ...
# Setting up python3-pil:amd64 (7.0.0-4ubuntu0.7) ...
# Setting up python3-packaging (20.3-1) ...
# Setting up libjs-jquery-ui (1.12.1+dfsg-5) ...
# Setting up python3-pandas (0.25.3+dfsg-7) ...
# /usr/lib/python3/dist-packages/pandas/tests/frame/test_alter_axes.py:241: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   False if (keys[0] is "A" and keys[1] is "A") else drop  # noqa: F632
# /usr/lib/python3/dist-packages/pandas/tests/frame/test_alter_axes.py:241: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   False if (keys[0] is "A" and keys[1] is "A") else drop  # noqa: F632
# Setting up python3-openpyxl (3.0.3-1) ...
# Setting up python3-pexpect (4.6.0-1build1) ...
# Setting up python3-h5py (2.10.0-2build2) ...
# Setting up python3-numexpr (2.7.1-1build1) ...
# Setting up python3-pluggy (0.13.0-2) ...
# Setting up libgoogle-glog0v5 (0.4.0-1build1) ...
# Setting up python3-imageio (2.4.1-3) ...
# /usr/lib/python3/dist-packages/imageio/plugins/_tifffile.py:2813: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if key is 0:
# Setting up python3-matplotlib (3.1.2-1ubuntu4) ...
# Setting up libcaffe-cpu1:amd64 (1.0.0+git20180821.99bd997-5build3) ...
# Setting up python3-pytest (4.6.9-1) ...
# Setting up python3-tables (3.6.1-2build1) ...
# Setting up caffe-tools-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Setting up python3-ipython (7.13.0-1) ...
# Setting up python3-skimage (0.16.2-2ubuntu1) ...
# Setting up python3-caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Setting up caffe-cpu (1.0.0+git20180821.99bd997-5build3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...

# %%
# IMPORTS

import torch
import torch.nn as nn
import numpy as np
import caffe
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
import urllib

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes: int = 1000, dropout: float = 0.5) -> None:
        super().__init__()
        self.features = nn.Sequential(    
            nn.Conv2d(3, 96, kernel_size=11, stride=4, padding=0),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.LocalResponseNorm(size=5),
            nn.Conv2d(96, 256, kernel_size=5, padding=2, groups=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.LocalResponseNorm(size=5),
            nn.Conv2d(256, 384, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 384, kernel_size=3, padding=1, groups=2),
            nn.ReLU(inplace=True),
            nn.Conv2d(384, 256, kernel_size=3, padding=1, groups=2),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.classifier = nn.Sequential(
            nn.Linear(9216, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(p=dropout),
            nn.Linear(4096, num_classes),
        )

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
net = AlexNet()
alexnet_weights = net.state_dict()
k = list(alexnet_weights.keys())

# %%
url, filename = ("https://github.com/pytorch/hub/raw/master/images/dog.jpg", "dog.jpg")
try: urllib.URLopener().retrieve(url, filename)
except: urllib.request.urlretrieve(url, filename)


input_image = Image.open(filename)

preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(227),
    transforms.ToTensor(),
])

# %%
caffe_net = caffe.Classifier("deploy_alexnet_updated.prototxt.txt", "bvlc_reference_caffenet.caffemodel",
                             mean = np.float32([104.0, 117.0, 123.0])) 
end = 'prob'
src = caffe_net.blobs['data']
w = caffe_net.blobs['data'].width
h = caffe_net.blobs['data'].height
input_tensor = 255*preprocess(input_image)-caffe_net.transformer.mean['data']

# %%
src.reshape(1,3,h,w)
src.data[0] = input_tensor.numpy()
acts = caffe_net.forward(end=end)
probabilities = torch.tensor(acts[end][0])

# Read the categories
with open("imagenet_classes.txt", "r") as f:
    categories = [s.strip() for s in f.readlines()]
# Show top categories per image
top5_prob, top5_catid = torch.topk(probabilities, 5)
for i in range(top5_prob.size(0)):
    print(categories[top5_catid[i]], top5_prob[i].item())

# %%
def shai_net_to_py_readable(prototxt_filename, caffemodel_filename):
  net = caffe.Net(prototxt_filename, caffemodel_filename, caffe.TEST) # read the net + weights
  pynet_ = [] 
  for li in range(len(net.layers)):  # for each layer in the net
    layer = {}  # store layer's information
    layer['name'] = net._layer_names[li]
    # for each input to the layer (aka "bottom") store its name and shape
    layer['bottoms'] = [(net._blob_names[bi], net.blobs[net._blob_names[bi]].data.shape) 
                         for bi in list(net._bottom_ids(li))] 
    # for each output of the layer (aka "top") store its name and shape
    layer['tops'] = [(net ._blob_names[bi], net.blobs[net._blob_names[bi]].data.shape) 
                      for bi in list(net._top_ids(li))]
    layer['type'] = net.layers[li].type  # type of the layer
    # the internal parameters of the layer. not all layers has weights.
    layer['weights'] = [net.layers[li].blobs[bi].data[...] 
                        for bi in range(len(net.layers[li].blobs))]
    pynet_.append(layer)
  return pynet_

# %%
res = shai_net_to_py_readable("deploy_alexnet_updated.prototxt.txt", ".caffemodel")
sub_res = []
for i in range(len(res)):
  if len(res[i]['weights']) > 0:
    sub_res.append(res[i]['weights'][0])
    sub_res.append(res[i]['weights'][1])
for i in range(16):
  assert alexnet_weights[k[i]].shape == torch.tensor(sub_res[i]).shape, "error"
  alexnet_weights[k[i]] = torch.tensor(sub_res[i])
k = list(alexnet_weights.keys())

# %%
net.load_state_dict(alexnet_weights)

# %%
net.eval()
with torch.no_grad():
  r = net(input_tensor.unsqueeze(0))
probabilities = torch.nn.functional.softmax(r[0], dim=0)
# Read the categories
with open("imagenet_classes.txt", "r") as f:
    categories = [s.strip() for s in f.readlines()]
# Show top categories per image
top5_prob, top5_catid = torch.topk(probabilities, 5)
for i in range(top5_prob.size(0)):
    print(categories[top5_catid[i]], top5_prob[i].item())

# %%
torch.save(net.state_dict(), "net.pt")

# %% [markdown]
# #TESTING

# %%
net = AlexNet()
net.load_state_dict(alexnet_weights)
hook = net.features[0].register_forward_hook(get)
hook.remove()

# %%
caffe_net = caffe.Classifier("deploy_alexnet_updated.prototxt.txt", "bvlc_reference_caffenet.caffemodel",
                             mean = np.float32([104.0, 117.0, 123.0])) 

src = caffe_net.blobs['data']
w = caffe_net.blobs['data'].width
h = caffe_net.blobs['data'].height

src.reshape(1,3,h,w)
src.data[0] = input_tensor.numpy()

acts = caffe_net.forward(end='conv1')
probabilities = torch.tensor(acts[end][0])


# Read the categories
with open("imagenet_classes.txt", "r") as f:
    categories = [s.strip() for s in f.readlines()]
# Show top categories per image
top5_prob, top5_catid = torch.topk(probabilities, 5)
for i in range(top5_prob.size(0)):
    print(categories[top5_catid[i]], top5_prob[i].item())
